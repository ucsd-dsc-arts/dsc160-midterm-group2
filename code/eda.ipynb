# %% [markdown]
# # EDA Notebook
# ### Purpose: Extract descriptive statistics about the dataset
# ### Reference: https://github.com/mdeff/fma/blob/master/analysis.ipynb

# %%
import numpy as np
import pandas as pd
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# load features.csv
features_path = os.path.join("..","..", "fma_metadata", "features.csv")
features = pd.read_csv(features_path, index_col=[0], header=[0,1,2])
features.head()
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2             7.180653  5.230309  0.249321  1.347620  1.482478  0.531371
# 3             1.888963  0.760539  0.345297  2.295201  1.654031  0.067592
# 5             0.527563 -0.077654 -0.279610  0.685883  1.937570  0.880839
# 10            3.702245 -0.291193  2.196742 -0.234449  1.367364  0.998411
# 20           -0.193837 -0.198527  0.201546  0.258556  0.775204  0.084794
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# track_id                                            ...
# 2           1.481593  2.691455  0.866868  1.341231  ...  0.054125  0.012226
# ...

# %%
# load tracks.csv
tracks_path = os.path.join("..","..", "fma_metadata", 'tracks.csv')
tracks = pd.read_csv(tracks_path, index_col=[0], header=[0,1])
tracks.head()
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#                                                                           \
#          favorites id                                information listens
# track_id
# 2                4  1                                    <p></p>    6073
# 3                4  1                                    <p></p>    6073
# 5                4  1                                    <p></p>    6073
# 10               4  6                                        NaN   47632
# ...

# %%
# load genres.csv
genres_path = os.path.join("..","..", "fma_metadata", 'genres.csv')
genres = pd.read_csv(genres_path, index_col=[0])
genres.head()
# Out:
#           #tracks  parent          title  top_level
# genre_id
# 1            8693      38    Avant-Garde         38
# 2            5271       0  International          2
# 3            1752       0          Blues          3
# 4            4126       0           Jazz          4
# 5            4106       0      Classical          5

# %% [markdown]
# # Desciptive Stats

# %%
print('{} tracks, {} artists, {} albums, {} genres'.format(
    len(tracks), len(tracks['artist', 'id'].unique()),
    len(tracks['album', 'id'].unique()),
    sum(genres['#tracks'] > 0)))
# Out:
# 106574 tracks, 16341 artists, 14854 albums, 161 genres

# %%
mean_duration = tracks['track', 'duration'].mean()
print('track duration: {:.0f} days total, {:.0f} seconds average'.format(
    sum(tracks['track', 'duration']) / 3600 / 24,
    mean_duration))
# Out:
# track duration: 343 days total, 278 seconds average

# %%
# Top 20 most popular genres
genres.sort_values(by='#tracks', ascending = False).title.iloc[0:20]
# Out:
# genre_id
# 38            Experimental
# 15              Electronic
# 12                    Rock
# 1235          Instrumental
# 10                     Pop
# 17                    Folk
# 25                    Punk
# 1              Avant-Garde
# 21                 Hip-Hop
# 32                   Noise
# 107                Ambient
# 76        Experimental Pop
# 41         Electroacoustic
# 27                   Lo-Fi
# 18              Soundtrack
# 42      Ambient Electronic
# 66              Indie-Rock
# 2            International
# 250                 Improv
# 103      Singer-Songwriter
# Name: title, dtype: object

# %% [markdown]
# # Descriptive Stats for 4 Unique Genres
#
# ### Electronic, Rock, Folk, Hip-Hop

# %%
tracks['Rock'] = tracks.track.genres_all.apply(lambda x: True if ('12' in x) else False )
tracks['Hiphop'] = tracks.track.genres_all.apply(lambda x: True if ('21' in x) else False )
tracks['Electronic'] = tracks.track.genres_all.apply(lambda x: True if ('15' in x) else False )
tracks['Folk'] = tracks.track.genres_all.apply(lambda x: True if ('17' in x) else False )

# %%
print('Average Rock Track Duration (in seconds): ', tracks[tracks['Rock'] == True].track.duration.mean().round())
print('Average Hiphop Track Duration (in seconds): ', tracks[tracks['Hiphop'] == True].track.duration.mean().round())
print('Average Electronic Track Duration (in seconds): ', tracks[tracks['Electronic'] == True].track.duration.mean().round())
print('Average Folk Track Duration (in seconds): ', tracks[tracks['Folk'] == True].track.duration.mean().round())
# Out:
# Average Rock Track Duration (in seconds):  255.0
# Average Hiphop Track Duration (in seconds):  208.0
# Average Electronic Track Duration (in seconds):  277.0
# Average Folk Track Duration (in seconds):  252.0

# %%
tracks[(tracks['Hiphop'] == True)].artist
# Out:
#             active_year_begin active_year_end  \
# track_id
# 2         2006-01-01 00:00:00             NaN
# 3         2006-01-01 00:00:00             NaN
# 5         2006-01-01 00:00:00             NaN
# 134       2006-01-01 00:00:00             NaN
# 583       2003-01-01 00:00:00             NaN
# ...                       ...             ...
# 155063    2015-01-01 00:00:00             NaN
# 155064    2015-01-01 00:00:00             NaN
# 155065    2015-01-01 00:00:00             NaN
# 155066    2015-01-01 00:00:00             NaN
# 155247                    NaN             NaN
#
#                                           associated_labels  \
# track_id
# 2                                                       NaN
# 3                                                       NaN
# 5                                                       NaN
# 134                                                     NaN
# 583                                            Hip Hop Slam
# ...

# %%
tracks.columns
# Out:
# MultiIndex([(     'album',          'comments'),
#             (     'album',      'date_created'),
#             (     'album',     'date_released'),
#             (     'album',          'engineer'),
#             (     'album',         'favorites'),
#             (     'album',                'id'),
#             (     'album',       'information'),
#             (     'album',           'listens'),
#             (     'album',          'producer'),
#             (     'album',              'tags'),
#             (     'album',             'title'),
#             (     'album',            'tracks'),
#             (     'album',              'type'),
#             (    'artist', 'active_year_begin'),
#             (    'artist',   'active_year_end'),
#             (    'artist', 'associated_labels'),
#             (    'artist',               'bio'),
#             (    'artist',          'comments'),
#             (    'artist',      'date_created'),
# ...
