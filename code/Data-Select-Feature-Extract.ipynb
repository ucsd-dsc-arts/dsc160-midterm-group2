# %%
import pandas as pd
import numpy as np

import os

import warnings
import random

# %%
warnings.filterwarnings("ignore")

features = pd.read_csv(os.path.join("..","..", "fma_metadata", "features.csv"), index_col=[0], header=[0,1,2])

features
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2             7.180653  5.230309  0.249321  1.347620  1.482478  0.531371
# 3             1.888963  0.760539  0.345297  2.295201  1.654031  0.067592
# 5             0.527563 -0.077654 -0.279610  0.685883  1.937570  0.880839
# 10            3.702245 -0.291193  2.196742 -0.234449  1.367364  0.998411
# 20           -0.193837 -0.198527  0.201546  0.258556  0.775204  0.084794
# ...                ...       ...       ...       ...       ...       ...
# 155316       -0.490129  0.463834  2.321970 -0.084352  1.662914  2.115189
# 155317       -0.461559 -0.229601 -0.496632 -0.422033  0.130612 -0.263825
# 155318        0.552473 -0.110498 -0.532014  0.263131 -0.224011 -0.530972
# 155319       -0.176901  0.187208 -0.050664  0.368843  0.066005 -0.857354
# ...

# %%
tracks = pd.read_csv(os.path.join("..","..", "fma_metadata", "tracks.csv"), index_col=[0], header=[0,1])

# %%
tracks['track']
# Out:
#           bit_rate  comments   composer         date_created  \
# track_id
# 2           256000         0        NaN  2008-11-26 01:48:12
# 3           256000         0        NaN  2008-11-26 01:48:14
# 5           256000         0        NaN  2008-11-26 01:48:20
# 10          192000         0  Kurt Vile  2008-11-25 17:49:06
# 20          256000         0        NaN  2008-11-26 01:48:56
# ...            ...       ...        ...                  ...
# 155316      320000         0        NaN  2017-03-30 15:23:34
# 155317      320000         0        NaN  2017-03-30 15:23:36
# 155318      320000         0        NaN  2017-03-30 15:23:37
# 155319      320000         0        NaN  2017-03-30 15:23:39
# 155320      320000         0        NaN  2017-03-30 09:15:36
#
#                 date_recorded  duration  favorites genre_top         genres  \
# track_id
# 2         2008-11-26 00:00:00       168          2   Hip-Hop           [21]
# ...

# %%
ROCK_ID = '12'
HOP_ID = '21'
ELEC_ID = '15'
FOLK_ID = '17'

# %%
tracks['Rock'] = tracks.track.genres.apply(lambda x: True if (ROCK_ID in x) else False )
tracks['Hiphop'] = tracks.track.genres.apply(lambda x: True if (HOP_ID in x) else False )
tracks['Electronic'] = tracks.track.genres.apply(lambda x: True if (ELEC_ID in x) else False )
tracks['Folk'] = tracks.track.genres.apply(lambda x: True if (FOLK_ID in x) else False )

# %%
random.seed(0)
SAMPLE_SIZE = 5000

# %%
rock_feat = features[tracks['Hiphop']].sample(5000, random_state=69)
rock_feat
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 12055        -0.832356 -0.337158 -0.828170  0.048357 -0.261407  0.533633
# 98578        -1.531577 -1.555636 -1.252186 -0.597757 -0.547555 -1.482620
# 122476        0.750563 -0.181086 -0.604546  0.426678  1.011579 -0.361774
# 21228         0.680527  0.483666  0.763739 -0.549255  0.298228 -0.458962
# 78999         0.931813 -0.177616 -0.027009  0.404298 -0.011802 -0.246839
# ...                ...       ...       ...       ...       ...       ...
# 26020         1.331944 -0.412853 -0.634550 -0.985005 -0.831315  0.033468
# 108440        0.180236 -0.081023 -0.171578 -0.183689  1.116489  0.173752
# 51537         1.269904 -1.405437 -0.850034 -1.175428 -1.106564  0.062348
# 76493        -0.571019 -0.262583 -0.704008  0.247145  1.246906  0.004294
# ...

# %%
hop_feat = features[tracks['Hiphop']].sample(5000, random_state=69)
hop_feat
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 12055        -0.832356 -0.337158 -0.828170  0.048357 -0.261407  0.533633
# 98578        -1.531577 -1.555636 -1.252186 -0.597757 -0.547555 -1.482620
# 122476        0.750563 -0.181086 -0.604546  0.426678  1.011579 -0.361774
# 21228         0.680527  0.483666  0.763739 -0.549255  0.298228 -0.458962
# 78999         0.931813 -0.177616 -0.027009  0.404298 -0.011802 -0.246839
# ...                ...       ...       ...       ...       ...       ...
# 26020         1.331944 -0.412853 -0.634550 -0.985005 -0.831315  0.033468
# 108440        0.180236 -0.081023 -0.171578 -0.183689  1.116489  0.173752
# 51537         1.269904 -1.405437 -0.850034 -1.175428 -1.106564  0.062348
# 76493        -0.571019 -0.262583 -0.704008  0.247145  1.246906  0.004294
# ...

# %%
elec_feat = features[tracks['Electronic']].sample(5000, random_state=69)
elec_feat
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 12025        -0.099040 -0.124299  0.506018 -0.196038  0.019240  1.005427
# 130995       -0.483437 -0.380203  0.048791 -0.459665 -0.233992 -0.326577
# 38841        -0.792864  0.293569  0.415994 -0.523765 -1.005317 -0.476416
# 3454          0.517294 -0.058364 -0.838312  0.064304  0.079583 -0.084198
# 154175       -0.767256 -1.176929  3.276625 -0.978736 -0.757906 -1.049738
# ...                ...       ...       ...       ...       ...       ...
# 9249         -0.312339 -0.297107  1.612139 -1.131017  3.104297 -0.859909
# 87745         1.610159  0.148835  0.793396  3.479002  3.832632 -0.050813
# 99291         0.532632  0.163834  1.996554  0.662594  0.099965 -0.157352
# 66906         0.259630  0.218307 -0.418425 -0.468121 -0.427849 -0.907501
# ...

# %%
folk_feat = features[tracks['Folk']].sample(5000, random_state=69)
folk_feat
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 62746        -0.696965  0.006735 -1.155382 -0.479574 -1.056154 -0.766975
# 22166        -1.009554 -0.621126 -0.524330  0.456779  1.262441  1.788291
# 98639        -0.287417 -0.372146  0.184902 -0.159734  0.031886  0.555696
# 1895          0.235878 -0.161256  0.251813 -0.595220 -0.862639 -0.597814
# 149820       -0.391394 -0.763959 -0.663588 -0.507054 -0.991957 -0.794695
# ...                ...       ...       ...       ...       ...       ...
# 119599       -0.877582 -0.619900 -0.838821 -0.083710 -0.946321  0.171299
# 145859        0.316286 -0.185944 -0.414013 -0.000954 -0.389134 -0.288937
# 65858        -0.467445 -0.022636 -0.269261 -0.347806 -0.247825 -0.691606
# 116458       -0.428384  0.259900 -0.531871  0.204335 -0.464105 -0.016302
# ...

# %%
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_FE = cosine_similarity(folk_feat, elec_feat)

# %%
[(index, index in have_it_elec) for index, num in sorted(enumerate(cosine_FE[0]), key=lambda x: x[-1], reverse=True)]
# Out:
# [(2089, False),
#  (1940, False),
#  (687, False),
#  (3673, False),
#  (2844, False),
#  (2841, False),
#  (2321, False),
#  (2536, False),
#  (1521, False),
#  (2765, False),
#  (2391, False),
#  (2832, False),
#  (260, False),
#  (4224, False),
#  (2511, False),
#  (1924, False),
#  (2857, False),
#  (4087, False),
#  (727, False),
#  (49, False),
#  (835, False),
#  (3000, False),
#  (3256, False),
#  (3291, False),
#  (3658, False),
#  (1411, False),
#  (1322, False),
#  (1171, False),
#  (4189, False),
#  (3681, False),
#  (108, False),
#  (2098, False),
#  (2416, False),
#  (3803, False),
#  (2020, False),
#  (2259, False),
#  (1701, False),
#  (1002, False),
#  (120, False),
#  (95, False),
#  (4827, False),
#  (1314, False),
#  (2399, False),
#  (4692, False),
#  (745, False),
#  (1827, False),
#  (257, False),
#  (3666, False),
#  (4391, False),
#  (4623, False),
#  (4104, False),
#  (35, False),
#  (106, False),
#  (1123, False),
#  (881, False),
#  (3785, False),
# ...

# %%
print(cosine_FE[1].argmax())
print(cosine_FE[1].max())
# Out:
# 1545
# 0.9995644285749087

# %%
998 in have_it
# Out:
# False

# %%
mp3s = []
for genre in os.listdir(AUDIO_DATA_PATH):
    rel_path = AUDIO_DATA_PATH + genre
    if os.path.isdir(rel_path):
        mp3s += [int(bob.strip('.mp3')) for bob in os.listdir(rel_path)]
# all of the track ids that are in the small fma set

# %%
have_it_elec = [idx in mp3s for idx in elec_feat.index]
have_it_elec
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
have_it_folk = [idx in mp3s for idx in folk_feat.index]
res = [i for i, val in enumerate(have_it) if val] 
res
# Out:
# [28,
#  34,
#  43,
#  47,
#  52,
#  56,
#  65,
#  68,
#  82,
#  83,
#  86,
#  104,
#  110,
#  118,
#  122,
#  132,
#  138,
#  145,
#  161,
#  163,
#  166,
#  181,
#  191,
#  200,
#  208,
#  210,
#  213,
#  216,
#  259,
#  268,
#  322,
#  328,
#  336,
#  338,
#  345,
#  354,
#  360,
#  371,
#  378,
#  423,
#  438,
#  465,
#  467,
#  482,
#  488,
#  498,
#  512,
#  515,
#  527,
#  529,
#  531,
#  532,
#  583,
#  600,
#  619,
#  621,
#  641,
#  646,
#  649,
#  656,
#  673,
#  680,
#  701,
#  703,
#  734,
#  737,
#  738,
#  739,
#  752,
#  755,
#  764,
#  776,
#  795,
#  827,
#  828,
#  839,
#  874,
#  904,
#  916,
#  925,
#  954,
#  958,
#  977,
#  999,
#  1001,
#  1027,
#  1032,
#  1056,
#  1059,
#  1077,
#  1082,
#  1086,
#  1096,
#  1100,
#  1108,
#  1109,
#  1113,
#  1124,
#  1146,
#  1148,
#  1160,
#  1161,
#  1170,
#  1200,
#  1204,
#  1214,
#  1226,
#  1230,
#  1241,
#  1244,
#  1254,
#  1255,
#  1262,
#  1269,
#  1270,
#  1285,
#  1301,
#  1312,
#  1358,
#  1371,
#  1392,
# ...

# %%
folk_feat[have_it]
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 124424       -0.196746  0.771951  0.819875  0.226184 -0.267177 -0.312799
# 12352        -0.753864 -1.411357  3.911828 -1.134575 -1.188377 -1.249555
# 148218       -0.559070 -0.922271 -0.593411  0.168073 -0.244668 -0.776122
# 87967        -0.577855  1.736144 -0.209336 -1.001842 -0.941875 -0.884627
# 51659        -0.983280 -0.755697 -0.666798 -0.730293 -0.338435 -0.784753
# ...                ...       ...       ...       ...       ...       ...
# 89350         0.706677  0.031271 -0.145972 -0.564192 -0.945040  1.002496
# 75869        -0.117389 -0.655279 -0.310645 -0.187673  0.332526 -0.008809
# 146961       -0.265616 -0.537066 -0.029398 -0.541497  0.562379 -0.671516
# 3265         24.463131  4.674429  9.707988  0.368159  0.426291  2.012475
# ...

# %%
cosine_FE
# Out:
# array([[0.97609564, 0.99011848, 0.95600465, ..., 0.98977636, 0.98929634,
#         0.99119779],
#        [0.9190327 , 0.94808893, 0.99357756, ..., 0.93865162, 0.94502045,
#         0.95577297],
#        [0.96357976, 0.98203586, 0.98486817, ..., 0.9735079 , 0.98263651,
#         0.98581288],
#        ...,
#        [0.95056738, 0.97190344, 0.99143001, ..., 0.96189251, 0.96780963,
#         0.97636457],
#        [0.97640171, 0.99076289, 0.97219348, ..., 0.98721826, 0.98700588,
#         0.99299542],
#        [0.96480162, 0.98092289, 0.96660398, ..., 0.97413715, 0.97526153,
#         0.97480649]])

# %%
AUDIO_DATA_PATH = '../../fma_small/'

# %%
tracks
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
# ...           ...                  ...                  ...      ...
# 155316          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155317          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155318          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155319          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155320          0  2017-03-26 16:22:18  2017-03-26 00:00:00      NaN
#
# ...
